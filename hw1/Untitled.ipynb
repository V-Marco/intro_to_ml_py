# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('FISH.csv')

# %%
data.head(10)
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# 5   Bream   450.0     26.8     29.7     34.7  13.6024  4.9274
# 6   Bream   500.0     26.8     29.7     34.5  14.1795  5.2785
# 7   Bream   390.0     27.6     30.0     35.0  12.6700  4.6900
# 8   Bream   450.0     27.6     30.0     35.1  14.0049  4.8438
# 9   Bream   500.0     28.5     30.7     36.2  14.2266  4.9594

# %%
data.shape
# Out:
# (159, 7)

# %%
data['Species'].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
data.columns = ['Species', 'Weight', 'VerLen', 'DiagVerLen', 'HorLen', 'DiagHorLen', 'Height']

# %%
data.head()
# Out:
#   Species  Weight  VerLen  DiagVerLen  HorLen  DiagHorLen  Height
# 0   Bream   242.0    23.2        25.4    30.0     11.5200  4.0200
# 1   Bream   290.0    24.0        26.3    31.2     12.4800  4.3056
# 2   Bream   340.0    23.9        26.5    31.1     12.3778  4.6961
# 3   Bream   363.0    26.3        29.0    33.5     12.7300  4.4555
# 4   Bream   430.0    26.5        29.0    34.0     12.4440  5.1340

# %%
plt.scatter( data['Height'], data['Weight'])

# %%
np.sum(data['Weight'].isna())
# Out:
# 1

# %%
plt.scatter(data['VerLen'], data['Height'])

# %%
import seaborn as sns
data = data.dropna()

# %%
corr = data.iloc[:, 1:].corr()

# %%
corr
# Out:
#               Weight    VerLen  DiagVerLen    HorLen  DiagHorLen    Height
# Weight      1.000000  0.916436    0.919370  0.924470    0.728695  0.887412
# VerLen      0.916436  1.000000    0.999517  0.992146    0.625854  0.866954
# DiagVerLen  0.919370  0.999517    1.000000  0.994209    0.640931  0.873450
# HorLen      0.924470  0.992146    0.994209  1.000000    0.703161  0.878413
# DiagHorLen  0.728695  0.625854    0.640931  0.703161    1.000000  0.793774
# Height      0.887412  0.866954    0.873450  0.878413    0.793774  1.000000

# %%
sns.heatmap(data.iloc[:, 1:])

# %%
data.iloc[:, 1:]
# Out:
#      Weight  VerLen  DiagVerLen  HorLen  DiagHorLen  Height
# 0     242.0    23.2        25.4    30.0     11.5200  4.0200
# 1     290.0    24.0        26.3    31.2     12.4800  4.3056
# 2     340.0    23.9        26.5    31.1     12.3778  4.6961
# 3     363.0    26.3        29.0    33.5     12.7300  4.4555
# 4     430.0    26.5        29.0    34.0     12.4440  5.1340
# 5     450.0    26.8        29.7    34.7     13.6024  4.9274
# 6     500.0    26.8        29.7    34.5     14.1795  5.2785
# 7     390.0    27.6        30.0    35.0     12.6700  4.6900
# 8     450.0    27.6        30.0    35.1     14.0049  4.8438
# 9     500.0    28.5        30.7    36.2     14.2266  4.9594
# 10    475.0    28.4        31.0    36.2     14.2628  5.1042
# 11    500.0    28.7        31.0    36.2     14.3714  4.8146
# 12    500.0    29.1        31.5    36.4     13.7592  4.3680
# 14    600.0    29.4        32.0    37.2     14.9544  5.1708
# 15    600.0    29.4        32.0    37.2     15.4380  5.5800
# ...

# %%
plt.hist(data['Weight'])
# Out:
# (array([59., 31., 11., 18., 16., 11.,  8.,  1.,  0.,  3.]),
#  array([   0.,  165.,  330.,  495.,  660.,  825.,  990., 1155., 1320.,
#         1485., 1650.]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(data['HorLen'], data['Weight'], c = pd.Categorical(data['Species']).codes)
plt.legend()
x = np.array([30, 60])
y = np.array([150, 1250])
plt.plot(x, y)
# Out:
# No handles with labels found to put in legend.

# %%
x = np.linspace(-3, 3)
y = np.sqrt(9 - x**2)

plt.xlim(-50, 50)
plt.ylim(-50, 50)
plt.plot(x, y)
plt.plot(x, -y)

# %%
rands = np.random.rand(100) * 20
x = np.arange(0, 100)
y = 3*x + rands

# %%
plt.plot(x, 3*x)
plt.plot(x, y)
