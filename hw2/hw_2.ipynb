# %% [markdown]
# ## Введение в анализ данных и машинное обучение на Python

# %% [markdown]
# ### Домашнее задание 2
# ### «Линейная регрессия. Метод kNN для задачи классификации. Решающие деревья»

# %% [markdown]
# ### Информация:
#
# __Дата выдачи:__ 19 января 2020
#
# __Крайний срок сдачи:__ 20 февраля 2020, 23:59:59
#
#
# __Про выполнение заданий:__
# 1. Все задания необходимо выполнять в данной тетрадке. При необходимости Вы можете создавать дополнительные клетки. Задания можно выполнять не по порядку.
# 2. Если в задании требуется предоставить комментарий, напишите его в отдельной ячейке Markdown. Вы также можете комментировать отдельные фрагменты кода, если посчитаете нужным.
# 3. Вопросы по формулировке заданий Вы можете задавать в чате Telegram.
# 4. Вы можете решать задания совместно со своими товарищами, однако оформление решения должно происходить индивидуально, чтобы не было подозрений на плагиат.
# 5. Вы можете использовать любые источники в Интернете, в том числе, использовать для решения заданий готовый, написанный кем-то, код. Однако в этом случае Вам необходимо предоставить __ссылку на источник__ (как комментарий перед частью используемого кода).
# 6. Количество баллов за каждое задание указано рядом с номером задания. Максимальное количество баллов, которое можно получить за работу – 10.
# 7. В конце работы напишите краткий вывод о том, что было сделано в работе, чему Вы научились.
#
# __Советы:__
# 1. Не забудьте в начале работы подключить необходимые библиотеки. Вы также можете подключать библиотеки в процессе выполнения работы.
# 2. Не забудьте установить `np.random.seed()` при работе со случайными данными.
# 3. Реализация всех используемых моделей содержится в библиотеке `sklearn`. Смотрите тетрадки с занятий.
#
# После завершения выполнения домашней работы, переименуйте файл в формате "фамилия_имя_группа.ipynb" (фамилию и имя нужно написать по-английски). Отправьте файл работы на vsomelyusik@gmail.com, указав в теме письма "HW2_Фамилия_Имя" (а здесь фамилию и имя нужно написать по-русски).

# %% [markdown]
# ### Обработка данных (3 балла)

# %% [markdown]
# В этом Домашнем задании Вы будете работать с тем же набором данных, который использовался в Домашнем задании №1. Некоторые упражнения, приведённые в этом разделе, повторяют представленные в прошлом Домашнем задании.
#
# В наборе данных __"Fish market"__ содержатся данные по характеристикам различных видов рыб.
#
# Датасет представлен на [kaggle.com](https://www.kaggle.com) – пожалуй, самом популярном сайте участия в соревнованиях по машинному обучению.
#
# [Описание и переменные](https://www.kaggle.com/aungpyaeap/fish-market)
#
# Описание переменных на русском:
# - `Species` – название вида рыбы на английском.
# - `Weight` – вес рыбы в граммах.
# - `Length1` – длина рыбы по вертикали (от головы к хвосту) в см.
# - `Length2` – длина рыбы по диагонали (от головы к хвосту) в см.
# - `Length3` – ширина рыбы по горизонтали (по спине) в см.
# - `Width` – ширина рыбы по диагонали (по спине) в см.
# - `Height` –  высота рыбы (по боковой стороне) в см.
#
# Предсказываемой переменной для задачи регрессия является переменная `Weight`.
#
# Предсказываемой переменной для задачи классификации является переменная `Species`.

# %% [markdown]
# __Задание 1__: Загрузите данные. Выведите первые 10 наблюдений.

# %% [markdown]
# __Задание 2:__ Определите:
# - число наблюдений;
# - число признаков;
# - типы признаков;
# - типы переменных `Weight` и `Species`.

# %% [markdown]
# __Задание 3:__ В оригинальном датасете переменные названы довольно неинформативно. Используя команду `a.columns = ` (где `a` – переменная, хранящая датасет), присвойте переменным следующие более информативные названия: Species, Weight, VerLen, DiagVerLen, HorLen, DiagHorLen, Height.

# %% [markdown]
# __Задание 4:__ Определите число пропущенных значений. Удалите наблюдения, имеющие пропущенные значения.

# %% [markdown]
# __Задание 5:__ Для задачи классификации нам потребуется бинарная зависимая переменная. Выведите уникальные виды рыб, встречающиеся в наборе данных. Найдите частоту, с которой встречается каждый из этих видов. Выберите тот вид рыб, которой является вторым по частоте встречаемости. Создайте переменную `Y_class` таким образом, что в ней стоят 1 для тех наблюдений, которые имеют выбранный Вами вид рыб, и 0 для всех остальных наблюдений.
#
# _(Если это задание окажется слишком сложным, напишите об этом в Telegram)._

# %% [markdown]
# __Задание 6:__ Выведите корреляционную матрицу переменных. Какие переменные наиболее коррелируют с переменной `Weight`? Выберите __три__ переменные, которые уместно включить в линейную модель. Поясните Ваш выбор.

# %% [markdown]
# __Задание 7:__ Сохраните переменную `Weight` как `Y_reg`. Сохраните выбранные Вами три независимых переменных в матрицу `X`.

# %% [markdown]
# __Задание 8:__ Разбейте полученные выборки $(X, Y_{reg})$ и $(X, Y_{class})$ на обучающие и тестовые (то есть у вас получится две подвыборки для каждой зависимой переменной). Установите размер тестовой выборки, равный 0.3. Не забудьте зафиксировать `np.random.seed`.

# %% [markdown]
# ### Парная регрессия (2 балла)

# %% [markdown]
# __Задание 1:__ Обучите парную регрессию вида:
# $$
# Y_{{reg}_i} = \beta_0 + \beta_1X_i + u_i,
# $$
# где $X$ – переменная, наиболее коррелирующая с зависимой переменной (Вы нашли её в Задании 6 предыдущего раздела).

# %% [markdown]
# __Задание 2:__ Выведите коэффициенты обученной модели. Определите тип зависимости (положительная или отрицательная). Приведите возможное объяснение такого типа зависимости.

# %% [markdown]
# __Задание 3:__ Сделайте предсказания на тестовой выборке. Получите MSE и $R^2$. Прокомментируйте результаты.

# %% [markdown]
# ### Множественная регрессия (2 балла)

# %% [markdown]
# __Задание 1:__ Обучите множественную регрессию вида:
# $$
# Y_{reg} = X\beta + u,
# $$
# где $X$ – матрица, содержащая все три отобранные Вами независимые переменные.

# %% [markdown]
# __Задание 2:__ Выведите коэффициенты модели. Сравните коэффициент перед переменной, которая использовалась при построении парной регрессии, с полученным в предыдущем разделе. Прокомментируйте результат.

# %% [markdown]
# __Задание 3:__ Сделайте предсказания на тестовой выборке. Получите MSE и $R^2$. Сравните качество предсказаний с парной регрессией из предыдущего раздела. Прокомментируйте результаты.

# %% [markdown]
# ### Метод k ближайших соседей (1 балл)

# %% [markdown]
# __Задание 1:__ Обучите классификатор `kNN` для 2, 5 и 12 ближайших соседей. Не забудьте, что рассматривается модель вида:
# $$
# Y_{class}(X)
# $$

# %% [markdown]
# __Задание 2:__ Сделайте предсказания на тестовой выборке. Используя в качестве метрики качества `accuracy`, выбрите оптимальное число ближайших соседей (то есть то, где `accuracy` наибольшая).

# %% [markdown]
# ### Решающие деревья. Случайный лес (2 балла)

# %% [markdown]
# __Задание 1:__ Вновь рассматривается модель вида
# $$
# Y_{class}(X)
# $$
# Обучите решающее дерево, никак не ограничивая его параметры. С какой проблемой сталкивается данный алгоритм?

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# __Задание 2:__ Обучите ещё одно решающее дерево, ограничив его глубину (параметр `max_depth`) на Ваше усмотрение.

# %% [markdown]
# __Задание 3:__ Сделайте предсказания на тестовой выборке для обоих деревьев. Сравните их качество по критерию `accuracy`. Прокомментируйте результаты.

# %% [markdown]
# __Задание 4:__ Обучите случайный лес для разного числа деревьев (попробуйте три разных варианта).

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# __Задание 5:__ Сделайте предсказания на тестовой выборке для всех обученных случайных лесов. Используя критерий `accuracy`, выберите оптимальное число деревьев.

# %% [markdown]
# __Задание 6:__ Сравните качество предсказаний лучшего случайного леса и лучшего дерева из Задания 3. Какая модель дала лучшее качество? Прокомментируйте результат.

# %% [markdown]
# __Задание 7:__ Сравните качество предсказаний лучшего алгоритма kNN и лучшей модели из Задания 6.
