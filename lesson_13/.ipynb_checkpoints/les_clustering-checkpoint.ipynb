# %% [markdown]
# ### Введение в анализ данных и машинное обучение на Python

# %% [markdown]
# ### Тема 13: Кластеризация (14 марта)

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Оригинальный набор данных ["Mouse"](https://github.com/elki-project/elki/blob/master/data/synthetic/Vorlesung/mouse.csv).
#
# Мы будем пользоваться обработанной версией.

# %%
data = pd.read_csv('data_mouse.csv', delimiter=';')

# %%
data.head(300)
# Out:
#       x_coord   y_coord  answ
# 0    0.456601  0.432806     0
# 1    0.611378  0.528625     0
# 2    0.450299  0.711606     0
# 3    0.639015  0.460744     0
# 4    0.628957  0.323470     0
# ..        ...       ...   ...
# 295  0.261665  0.670442     1
# 296  0.203042  0.734798     1
# 297  0.306490  0.690292     1
# 298  0.284278  0.738366     1
# 299  0.205310  0.742817     1
#
# [300 rows x 3 columns]

# %%
plt.scatter(data.x_coord, data.y_coord)

# %% [markdown]
# __Задание 0:__ Зафиксируйте `np.random.seed()`.
#
# Подготовьте обучающую выборку: используя команду `.sample(frac=...).reset_index(drop=...)` перемешайте наблюдения в исходной выборке.

# %%
np.random.seed(123)
train = data.sample(frac=1).reset_index(drop=True)

# %%
train.head(15)
# Out:
#      x_coord   y_coord  answ
# 0   0.609493  0.606362     0
# 1   0.306565  0.351961     0
# 2   0.386077  0.558459     0
# 3   0.767339  0.772006     2
# 4   0.688696  0.641825     0
# 5   0.566210  0.289358     0
# 6   0.480223  0.398718     0
# 7   0.716596  0.496177     0
# 8   0.350760  0.473150     0
# 9   0.761047  0.766616     2
# 10  0.494743  0.559715     0
# 11  0.644679  0.763977     2
# 12  0.205310  0.742817     1
# 13  0.678768  0.544417     0
# 14  0.753402  0.799368     2

# %% [markdown]
# __Задание 1:__  Импортируйте классы `KMeans`, `DBSCAN` из модуля `sklearn.cluster`.

# %%
from sklearn.cluster import KMeans, DBSCAN

# %% [markdown]
# __Задание 2:__ Обучите кластеризатор KMeans с нужным числом кластеров. Сделайте предсказания. Постройте графики с раскраской по предсказанным и истинным значениям. Оцените качество кластеризации.

# %%
kmeans = KMeans(n_clusters=3)
preds = kmeans.fit_predict(train)

# %%
preds

# %%
plt.scatter(train.x_coord, train.y_coord, c=preds)

# %%
plt.scatter(train.x_coord, train.y_coord, c=train.answ)

# %%
kmeans_2 = KMeans(n_clusters=2)
kmeans_5 = KMeans(n_clusters=5)

preds2 = kmeans_2.fit_predict(train)
preds5 = kmeans_5.fit_predict(train)

# %%
plt.scatter(train.x_coord, train.y_coord, c=preds2)

# %%
plt.scatter(train.x_coord, train.y_coord, c=preds5)

# %% [markdown]
# __Задание 3:__ Обучите кластеризатор DBSCAN со следующими вариантами параметра `eps`:
# - default
# - 0.05
# - 0.03
# - 0.02
# - 0.01
# - 0.001
#
# Сделайте предсказания. Постройте графики с раскраской по предсказанным и истинным значениям. Оцените качество кластеризации.

# %%
dbscan_default = DBSCAN(eps=0.001)
pred_dd = dbscan_default.fit_predict(train)
plt.scatter(train.x_coord, train.y_coord, c=pred_dd)
