# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(123)
sns.set()
# Out:
# Matplotlib is building the font cache using fc-list. This may take a moment.

# %%
random_x = np.arange(100, 200) + np.random.randint(10, 50, size=(100))

# %%
random_y = np.arange(10, 110) + np.random.randint(1, 10, size=(100))

# %%
outliers_x = np.array([140, 180, 220])
outliers_y = np.array([80, 120, 40])

# %%
line_x = np.arange(100, 200) + 27
line_y = np.arange(10, 110)

line_x = [120, 240]
line_y = [10, 120]

# %%
plt.scatter(random_x, random_y, alpha = 0.7)
plt.scatter(outliers_x, outliers_y, alpha = 0.7)
#plt.plot(line_x, line_y, linewidth = 3, c = 'green')
plt.title('Зависимость числа проданных в месяц ложек от числа проданных кружек')
plt.xlabel('Число проданных кружек (в мес.)')
plt.ylabel('Число проданных ложек (в мес.)')
# Out:
# Text(0, 0.5, 'Число проданных ложек (в мес.)')

# %%
random_x
# Out:
# array([142, 141, 115, 144, 141, 130, 143, 131, 139, 149, 140, 152, 128,
#        155, 131, 138, 150, 158, 155, 130, 146, 157, 133, 140, 171, 154,
#        172, 157, 163, 169, 159, 146, 156, 143, 169, 173, 147, 168, 176,
#        157, 170, 182, 183, 192, 179, 167, 158, 188, 190, 191, 172, 166,
#        165, 200, 169, 167, 192, 206, 187, 186, 189, 200, 181, 195, 176,
#        183, 194, 212, 217, 205, 207, 188, 189, 200, 204, 197, 212, 226,
#        203, 228, 198, 217, 208, 195, 197, 234, 196, 210, 205, 205, 229,
#        225, 240, 218, 214, 229, 238, 227, 217, 217])

# %%
plt.hist(random_x, alpha = 0.7)
plt.title('Гистограмма: Число проданных кружек')
plt.xlabel('Число проданных кружек')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')
